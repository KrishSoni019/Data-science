# %% [markdown]
# # Arthematic

# %%
a = 10
b = 5

# %%
a+b
# Out:
# 15

# %%
a-b
# Out:
# 5

# %%
a*b
# Out:
# 50

# %%
a/b
# Out:
# 2.0

# %%
a//b
# Out:
# 2

# %%
a%b # Module (Remainder)
# Out:
# 0

# %%
a**b # power
# Out:
# 100000

# %% [markdown]
# # Assignment

# %%
c = 20

# %%
c +=10

# %%
c -=10

# %%
c *=10

# %%
c /= 10

# %% [markdown]
# ... more

# %% [markdown]
# # Comparison

# %%
5==5
# Out:
# True

# %%
5!=3
# Out:
# True

# %%
5>3
# Out:
# True

# %%
5<3
# Out:
# False

# %%
5>=3
# Out:
# True

# %%
5<=3
# Out:
# False

# %% [markdown]
# # Logical

# %%
b1 = True
b2 = False

# %%
b1 and b2
# Out:
# False

# %%
b1 or b2
# Out:
# True

# %%
not(b1) # "not"  oprator will reverse the Result.
not(b2)
# Out:
# True

# %% [markdown]
# # Membership

# %%
lst = ["Krish" ,"Soni" , "MITWPU" ,"MCA"]

# %%
find = "MCA"

# %%
find in lst
# Out:
# True

# %%
find not in lst
# Out:
# False

# %% [markdown]
# # Identity

# %%
name ="Krish"
sname ="Soni"

# %%
name is sname
# Out:
# False

# %%
name is not sname
# Out:
# True
