# %%
import json

# %%
obj = {"name":"krish","course":"mca","age":20})

# %%
s = json.dumps(obj,indent=4)

# %%
s
# Out:
# '{\n    "name": "krish",\n    "course": "mca",\n    "age": 20\n}'

# %%
type(obj)
# Out:
# dict

# %%
type(s)
# Out:
# str

# %%
file = open("data.json","w")

# %%
json.dump(obj,file)

# %%
file.close()

# %%
f = open("data.json","r")

# %%
pd=json.load(f)

# %%
print(pd)
# Out:
# {'name': 'krish', 'course': 'mca', 'age': 20}
