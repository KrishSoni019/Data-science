# %%
cude = lambda x:x*x*x

# %%
cude(3)
# Out:
# 27

# %%
nums=[2,3,4,5]

# %%
sqr = list(map(lambda x:x*x,nums))

# %%
sqr
# Out:
# [4, 9, 16, 25]

# %%
data = {"a": 3, "b": 1, "c": 2}

sorted_data = dict(sorted(data.items(), key=lambda item: item[1]))
print(sorted_data)
# Out:
# {'b': 1, 'c': 2, 'a': 3}
