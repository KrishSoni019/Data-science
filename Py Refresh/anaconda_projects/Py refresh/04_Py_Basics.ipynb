# %% [markdown]
# ## If Else

# %%
a = 47

# %%
if (a>34):
    print("a is greater.")
else:
    print("a is smaller")
# Out:
# a is greater.

# %%
b = 11

# %%
if b>55:
    print("greater than 55.")
elif b>30:
    print("Greater than 30.")
elif b>10:
    print("Greater than 10.")
else:
    print("Less than 10.")
# Out:
# Greater than 10.

# %% [markdown]
# ## Function

# %%
def avg(a,b):
    return (a+b)/2

# %%
avg(5,3)
# Out:
# 4.0
