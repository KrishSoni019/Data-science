# %%
A = 5.5

# %%
B = 32

# %%
A + B
# Out:
# 37

# %%
name  =  "Krish"

# %%
print(name) # Hey its a Comment
# Out:
# Krish

# %%
print(type(A))
print(type(B))
print(type(name))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %%
c = "757"
d = "555" # Both String

# %%
print(int(c) + int(d)) # TypeCasting
# Out:
# 1312
