# %%
name = "Krrish"

# %%
print(name.upper())
print(name.lower())
# Out:
# KRRISH
# krrish

# %%
imagename = "Krish.jpg"
print(imagename.startswith("K"))
print(imagename.endswith(".jpg"))
# Out:
# True
# True

# %%
print(name.count("r"))
# Out:
# 2

# %%
print(len(name))
# Out:
# 6

# %%
a ="  removeSpaces    "
print(a.strip())
# Out:
# removeSpaces

# %%
b = "Hello Python"
print(b.replace("Python","Krish"))
# Out:
# Hello Krish

# %%
Str = "apple,banana,graps,pineapple"
STR = ["apple","banana","graps","pineapple"]
print(Str.split(","))
print(",".join(STR))
# Out:
# ['apple', 'banana', 'graps', 'pineapple']
# apple,banana,graps,pineapple

# %%
print(b.find("P"))
# Out:
# 6

# %%
c = "Heyy Python Devloper."
print("Heyy" in c)
print("Java" not in c)
# Out:
# True
# True

# %%
print(c[0:8])
# Out:
# Heyy Pyt
